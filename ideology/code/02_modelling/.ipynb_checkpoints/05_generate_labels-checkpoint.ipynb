# %%
from dotenv import load_dotenv
import os
import pandas as pd
load_dotenv()
base_dir = os.getenv('BASEDIR')
from pathlib import Path
import re
import pickle as pk
import numpy as np
from sklearn.metrics import f1_score, roc_auc_score
# from lightgbm import LGBMClassifier
from flaml.default import LGBMClassifier

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
datasets = ['qanda', 'ausvotes','socialsense','riot', 'parler']
# datasets = ['riot']

# %%
datasets_twitter = {'qanda', 'ausvotes', 'riot'}

# %%
gt_fr_name = 'URLb_FR'
for dataset in datasets:
    if dataset in datasets_twitter:
        features_lr=['use', 'rt']
        features_fr=['use', 'ht']
        # features_fr= ['use']
    else:
        features_lr= ['use']
        features_fr= ['use']
    
    granularity='_per_user'
    gt='URL_LR'
    data_path = os.path.join(base_dir,'data','01_raw_data',dataset, dataset+granularity+'.pk')
    with open(data_path, 'rb') as rf:
        data = pk.load(rf).reset_index(drop=False)
        
    def load_vector(fp):
        with open(fp, 'rb') as rf:
            vec = pk.load(rf)
        return vec
    
    feature_paths_lr = [os.path.join(base_dir,'data','03_processed',dataset,'features', dataset+'_'+feature+'_'+granularity+'.pk') for feature in features_lr]
    features_lr = np.asarray(np.hstack([load_vector(fp) for fp in feature_paths_lr]))
    
    feature_paths_fr = [os.path.join(base_dir,'data','03_processed',dataset,'features', dataset+'_'+feature+'_'+granularity+'.pk') for feature in features_fr]
    features_fr = np.asarray(np.hstack([load_vector(fp) for fp in feature_paths_fr]))
    
    gt_stance = load_vector(os.path.join(base_dir,'data','03_processed',dataset,'ground_truth', dataset+'_URL_LR_'+granularity+'.pk'))
    gt_fr = load_vector(os.path.join(base_dir,'data','03_processed',dataset,'ground_truth', dataset+'_'+gt_fr_name+'_'+granularity+'.pk'))    

    # Left-Right
    # et = LGBMClassifier(n_estimators=100, min_data_in_leaf=500,colsample_bytree=0.8, class_weight='balanced', n_jobs=-1)
    et = LGBMClassifier(is_unbalance=True,n_estimators=200, n_jobs=-1, verbose=-1, seed=123)
    mask_stance = gt_stance >=0
    y_stance = gt_stance[mask_stance]
    X_stance = features_lr[mask_stance]
    et.fit(X_stance,y_stance)
    predicted_stance = et.predict(features_lr)
    
    # Far-Right
    # et = LGBMClassifier(n_estimators=100, min_data_in_leaf=500,colsample_bytree=0.8, class_weight='balanced', n_jobs=-1)
    et = LGBMClassifier(is_unbalance=True, n_jobs=-1, verbose=-1, seed=123)
    # et = LGBMClassifier(n_estimators=200, n_jobs=-1, verbose=-1, seed=123)
    mask_fr = gt_fr >=0
    y_fr = gt_fr[mask_fr]
    X_fr = features_fr[mask_fr]
    et.fit(X_fr,y_fr)
    predicted_fr = et.predict(features_fr)
    
    # probs_fr = et.predict_proba(features_fr)[:,1]
    # plt.figure()
    # sns.histplot(x=probs_fr)
    # break
                        
    pred_stance = pd.Series([['N', 'L', 'R'][i] for i in predicted_stance]).values
    
    label = pred_stance
    label[predicted_fr] = 'FR'
    data['label'] = label
    
    # print(dataset)
    # print("Number of FR in GT, and size of GT: ", np.sum(y_fr), len(y_fr))
    # print(data.groupby('label').count())
    # print('')
    
    Path(os.path.join(base_dir,'data','04_results','labels')).mkdir( parents=True, exist_ok=True )
    data[['uid','label']].to_csv(os.path.join(base_dir,'data','04_results','labels',dataset+'.csv'))
# Out:
# qanda
# Number of FR in GT, and size of GT:  269 103074
#          uid  level_1   text  hashtags    rid   urls
# label
# FR       746      746    746       746    746    746
# L      80375    80375  80375     80375  80375  80375
# N      21176    21176  21176     21176  21176  21176
# R        777      777    777       777    777    777
#
# ausvotes
# Number of FR in GT, and size of GT:  1630 273874
#           uid  level_1    text     rid    urls  hashtags
# label
# FR       1731     1731    1731    1731    1731      1731
# L      189233   189233  189233  189233  189233    189233
# N       79221    79221   79221   79221   79221     79221
# R        3689     3689    3689    3689    3689      3689
#
# socialsense
# Number of FR in GT, and size of GT:  215 49442
#          uid  level_1   text   urls
# label
# FR       318      318    318    318
# L      48056    48056  48056  48056
# N        604      604    604    604
# R        464      464    464    464
#
# riot
# Number of FR in GT, and size of GT:  865 574281
#           uid  level_1    text     rid    urls  hashtags
# label
# FR       3723     3723    3723    3723    3723      3723
# L      339095   339095  339095  339095  339095    339095
# N      227839   227839  227839  227839  227839    227839
# R        3624     3624    3624    3624    3624      3624
#
# parler
# Number of FR in GT, and size of GT:  1469 120048
#          uid  level_1   text    rid   urls
# label
# FR      2822     2822   2822   2822   2822
# L        293      293    293    293    293
# N      48829    48829  48829  48829  48829
# R      68104    68104  68104  68104  68104

# %%
from dotenv import load_dotenv
import os
import pandas as pd
load_dotenv()
base_dir = os.getenv('BASEDIR')
from pathlib import Path
import re
import pickle as pk
import numpy as np
from sklearn.metrics import f1_score, roc_auc_score
# from lightgbm import LGBMClassifier
from flaml.default import LGBMClassifier

from tqdm import tqdm

# %%
datasets = ['qanda', 'ausvotes','socialsense','riot', 'parler']
# datasets = ['riot']

# %%
datasets_twitter = {'qanda', 'ausvotes', 'riot'}

# %%
gt_fr_name = 'URLb_FR'
for dataset in tqdm(datasets):
    if dataset in datasets_twitter:
        features_lr=['use', 'rt']
        features_fr=['use', 'ht']
        # features_fr= ['use']
    else:
        features_lr= ['use']
        features_fr= ['use']
    
    granularity='_per_user'
    gt='URL_LR'
    data_path = os.path.join(base_dir,'data','01_raw_data',dataset, dataset+granularity+'.pk')
    with open(data_path, 'rb') as rf:
        data = pk.load(rf).reset_index(drop=False)
        
    def load_vector(fp):
        with open(fp, 'rb') as rf:
            vec = pk.load(rf)
        return vec
    
    feature_paths_lr = [os.path.join(base_dir,'data','03_processed',dataset,'features', dataset+'_'+feature+'_'+granularity+'.pk') for feature in features_lr]
    features_lr = np.asarray(np.hstack([load_vector(fp) for fp in feature_paths_lr]))
    
    feature_paths_fr = [os.path.join(base_dir,'data','03_processed',dataset,'features', dataset+'_'+feature+'_'+granularity+'.pk') for feature in features_fr]
    features_fr = np.asarray(np.hstack([load_vector(fp) for fp in feature_paths_fr]))
    
    gt_stance = load_vector(os.path.join(base_dir,'data','03_processed',dataset,'ground_truth', dataset+'_URL_LR_'+granularity+'.pk'))
    gt_fr = load_vector(os.path.join(base_dir,'data','03_processed',dataset,'ground_truth', dataset+'_'+gt_fr_name+'_'+granularity+'.pk'))    

    # Left-Right
    et = LGBMClassifier(is_unbalance=True,n_estimators=200, n_jobs=-1, verbose=-1, seed=41)
    mask_stance = gt_stance >=0
    y_stance = gt_stance[mask_stance]
    X_stance = features_lr[mask_stance]
    print('Training:', 'lr')
    et.fit(X_stance,y_stance)
    print('Trained:', 'lr')
    predicted_stance = et.predict(features_lr)
    predicted_stance_proba = et.predict_proba(features_lr)
    
    # Far-Right
    et = LGBMClassifier(is_unbalance=True, n_jobs=-1, verbose=-1, seed=123)
    mask_fr = gt_fr >=0
    y_fr = gt_fr[mask_fr]
    X_fr = features_fr[mask_fr]
    print('Training:', 'fr')
    et.fit(X_fr,y_fr)
    print('Trained:', 'fr')
    predicted_fr = et.predict(features_fr)
    predicted_fr_proba = et.predict_proba(features_fr)
                        
    pred_stance = pd.Series([['N', 'L', 'R'][i] for i in predicted_stance]).values
    
    label = pred_stance
    label[predicted_fr] = 'FR'
    data['label'] = label
    data['lr_prob_left'] = predicted_stance_proba[:,1]

    data['lr_prob_right'] = predicted_stance_proba[:,2]

    data['lr_label'] = pd.Series([['N', 'L', 'R'][i] for i in predicted_stance]).values

    data['fr_prob'] = predicted_fr_proba[:,1]

    data['fr_label'] = predicted_fr

    Path(os.path.join(base_dir,'data','04_results','labels')).mkdir( parents=True, exist_ok=True )
    data[['uid','label','lr_prob_left','lr_prob_right', 'lr_label', 'fr_prob', 'fr_label']].to_csv(os.path.join(base_dir,'data','04_results','labels',dataset+'_extended.csv'))
# Out:
#   0%|                                                                                                                                                                                    | 0/5 [00:00<?, ?it/s]
# Training: lr
# Trained: lr
# Training: fr
# Trained: fr
#   0%|                                                                                                                                                                                  | 0/5 [1:09:41<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /data/roram/anaconda3/envs/rr/lib/python3.10/site-packages/pandas/core/indexes/base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File /data/roram/anaconda3/envs/rr/lib/python3.10/site-packages/pandas/_libs/index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File /data/roram/anaconda3/envs/rr/lib/python3.10/site-packages/pandas/_libs/index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lr_prob'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File /data/roram/anaconda3/envs/rr/lib/python3.10/site-packages/pandas/core/frame.py:3751, in DataFrame._set_item_mgr(self, key, value)
#    3750 try:
# -> 3751     loc = self._info_axis.get_loc(key)
#    3752 except KeyError:
#    3753     # This item wasn't present, just insert at end
#
# File /data/roram/anaconda3/envs/rr/lib/python3.10/site-packages/pandas/core/indexes/base.py:3363, in Index.get_loc(self, key, method, tolerance)
#    3362     except KeyError as err:
# -> 3363         raise KeyError(key) from err
#    3365 if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'lr_prob'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#      56 label[predicted_fr] = 'FR'
#      57 data['label'] = label
# ---> 59 data['lr_prob'] = predicted_stance_proba
#      60 data['lr_label'] = predicted_stance
#      62 data['fr_prob'] = predicted_fr_proba
#
# File /data/roram/anaconda3/envs/rr/lib/python3.10/site-packages/pandas/core/frame.py:3612, in DataFrame.__setitem__(self, key, value)
#    3609     self._setitem_array([key], value)
#    3610 else:
#    3611     # set column
# -> 3612     self._set_item(key, value)
#
# File /data/roram/anaconda3/envs/rr/lib/python3.10/site-packages/pandas/core/frame.py:3797, in DataFrame._set_item(self, key, value)
#    3794         if isinstance(existing_piece, DataFrame):
#    3795             value = np.tile(value, (len(existing_piece.columns), 1)).T
# -> 3797 self._set_item_mgr(key, value)
#
# File /data/roram/anaconda3/envs/rr/lib/python3.10/site-packages/pandas/core/frame.py:3754, in DataFrame._set_item_mgr(self, key, value)
#    3751     loc = self._info_axis.get_loc(key)
#    3752 except KeyError:
#    3753     # This item wasn't present, just insert at end
# -> 3754     self._mgr.insert(len(self._info_axis), key, value)
#    3755 else:
#    3756     self._iset_item_mgr(loc, value)
#
# File /data/roram/anaconda3/envs/rr/lib/python3.10/site-packages/pandas/core/internals/managers.py:1162, in BlockManager.insert(self, loc, item, value)
#    1159 else:
#    1160     value = ensure_block_shape(value, ndim=self.ndim)
# -> 1162 block = new_block(values=value, ndim=self.ndim, placement=slice(loc, loc + 1))
#    1164 for blkno, count in _fast_count_smallints(self.blknos[loc:]):
#    1165     blk = self.blocks[blkno]
#
# File /data/roram/anaconda3/envs/rr/lib/python3.10/site-packages/pandas/core/internals/blocks.py:1937, in new_block(values, placement, ndim, klass)
#    1934     placement = BlockPlacement(placement)
#    1936 values, _ = extract_pandas_array(values, None, ndim)
# -> 1937 check_ndim(values, placement, ndim)
#    1939 if klass is None:
#    1940     klass = get_block_type(values, values.dtype)
#
# File /data/roram/anaconda3/envs/rr/lib/python3.10/site-packages/pandas/core/internals/blocks.py:1979, in check_ndim(values, placement, ndim)
#    1974         raise ValueError(
#    1975             "Wrong number of dimensions. "
#    1976             f"values.ndim != ndim [{values.ndim} != {ndim}]"
#    1977         )
#    1978     if len(placement) != len(values):
# -> 1979         raise ValueError(
#    1980             f"Wrong number of items passed {len(values)}, "
#    1981             f"placement implies {len(placement)}"
#    1982         )
#    1983 elif ndim == 2 and len(placement) != 1:
#    1984     # TODO(EA2D): special case unnecessary with 2D EAs
#    1985     raise ValueError("need to split")
#
# ValueError: Wrong number of items passed 3, placement implies 1

# %%
data['lr_prob_left'] = predicted_stance_proba[:,1]

data['lr_prob_right'] = predicted_stance_proba[:,2]

data['lr_label'] = pd.Series([['N', 'L', 'R'][i] for i in predicted_stance]).values

data['fr_prob'] = predicted_fr_proba[:,1]

data['fr_label'] = predicted_fr

Path(os.path.join(base_dir,'data','04_results','labels')).mkdir( parents=True, exist_ok=True )
data[['uid','label','lr_prob_left','lr_prob_right', 'lr_label', 'fr_prob', 'fr_label']].to_csv(os.path.join(base_dir,'data','04_results','labels',dataset+'_extended.csv'))

# %%
predicted_stance
# Out:
# array([0, 1, 1, ..., 1, 1, 1])

# %%
predicted_stance_proba[:,1]
# Out:
# array([0.29330231, 0.99298013, 0.99981708, ..., 0.99591776, 0.9874386 ,
#        0.99372335])

# %%
data['lr_prob_left'] = predicted_stance_proba[:,1]

data['lr_prob_right'] = predicted_stance_proba[:,2]

data['lr_label'] = pred_stance

data['fr_prob'] = predicted_fr_proba[:,1]

data['fr_label'] = predicted_fr

Path(os.path.join(base_dir,'data','04_results','labels')).mkdir( parents=True, exist_ok=True )
data[['uid','label','lr_prob_left','lr_prob_right', 'lr_label', 'fr_prob', 'fr_label']].to_csv(os.path.join(base_dir,'data','04_results','labels',dataset+'_extended.csv'))

# %%
data
# Out:
#                         uid  level_1  \
# 0       1000001245946490880        0
# 1       1000022700092411904        0
# 2       1000111986917572608        0
# 3       1000127207048728576        0
# 4       1000175125608583168        0
# ...                     ...      ...
# 103069   999931831364435968        0
# 103070   999937171766235136        0
# 103071   999954234119356416        0
# 103072   999960633960316929        0
# 103073   999968158231363585        0
#
#                                                      text  \
# 0        here we come!!  is   with  1st March!  on  no...
# 1        when will you invite  on   Australian childre...
# 2       My daughter was lucky to finish her diploma bu...
# 3       Will you be one of the 99.99% of Australians n...
# 4        wheeling out clickbait promos that feed a def...
# ...                                                   ...
# 103069  RT  Meyne Wyatt closes  with a monologue from ...
# 103070      I said prior to this particular Q&amp;A sh...
# 103071  I know some folks are miffed I didn't get more...
# 103072  RT  Rio Tinto “oops we didnt know it was that ...
# 103073   The apprenticeship scheme sounds great, howev...
#
#                                                  hashtags  \
# 0       [Wolverhampton, screening, QandA, Tickets, sal...
# 1                                  [qanda, GretaThunberg]
# 2       [QandA, qanda, universities, QandA, qanda, shu...
# 3       [blacklivesmatteraustralia, auspol, qanda, 9to...
# 4       [QandA, aussieED, qanda, aussieED, qanda, wome...
# ...                                                   ...
# 103069                                            [QandA]
# 103070                                     [DefundTheABC]
# 103071                                            [QandA]
# 103072                         [qanda, QandA, auspol2020]
# 103073                                                 []
#
#                                                       rid  \
# 0                                   [1225781455386796033]
# 1                                   [1236486564550565888]
# 2       [1297865209139228672, 1300401525051645953, 122...
# 3                                   [1269083271930896384]
# 4       [1235133197601492994, 1235107041477156865, 123...
# ...                                                   ...
# 103069                              [1269982640494411776]
# 103070  [1270989483844841473, 1270989483844841473, 130...
# 103071         [1224309168909082625, 1269982640494411776]
# 103072         [1267430023620788227, 1320679824331993088]
# 103073                              [1313077187893841920]
#
#                                                      urls label  lr_prob_left  \
# 0               [http://light-house.co.uk/LightHouseMedi]     N      0.293302
# 1                                                      []     L      0.992980
# 2                                                      []     L      0.999817
# 3                                                      []     L      0.793648
# 4       [https://www.abc.net.au/qanda/2020-27-04/12165...     L      0.999689
# ...                                                   ...   ...           ...
# 103069                                                 []     L      0.997396
# 103070                                                 []     L      0.974676
# 103071                                                 []     L      0.995918
# 103072                                                 []     L      0.987439
# 103073                                                 []     L      0.993723
#
#         lr_prob_right lr_label   fr_prob  fr_label
# 0            0.003465        N  0.000076     False
# 1            0.000464        L  0.000237     False
# 2            0.000127        L  0.000214     False
# 3            0.014002        L  0.000277     False
# 4            0.000066        L  0.000810     False
# ...               ...      ...       ...       ...
# 103069       0.000515        L  0.000039     False
# 103070       0.022946        L  0.040587     False
# 103071       0.000132        L  0.000085     False
# 103072       0.001694        L  0.000108     False
# 103073       0.001650        L  0.000061     False
#
# [103074 rows x 12 columns]

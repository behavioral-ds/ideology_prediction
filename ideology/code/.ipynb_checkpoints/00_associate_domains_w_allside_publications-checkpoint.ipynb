# %%
from dotenv import load_dotenv
import os
import pandas as pd
load_dotenv()
from gdtm.helpers.common import load_flat_dataset

base_dir = os.getenv('BASEDIR')

# %%
from tqdm import tqdm
tqdm.pandas()

# %%
data = pd.read_csv(os.path.join(base_dir, 'data', '01_raw', 'allsides_data.csv'))

# %%
data= data[~data['rating_num'].isna()]

# %%
import requests
from bs4 import BeautifulSoup
import re
def get_domain(news_source):
    page = requests.get("https://www.google.com/search?q={news_source}".format(news_source=news_source))
    soup = BeautifulSoup(page.content)
    links = soup.find_all("a",href=re.compile("(?<=/url\?q=)(htt.*://.*)"))
    return(re.split(":(?=http)",links[0]["href"].replace("/url?q=",""))[0])

# %%
data['type'].unique()
# Out:
# array(['Think Tank / Policy Group', 'News Media', 'Author'], dtype=object)

# %%
data['news_source']
# Out:
# 0                   AARP
# 1               ABC News
# 3      Accuracy in Media
# 4                   ACLU
# 5                    AJ+
#              ...
# 541       William McGurn
# 542    Wisconsin Gazette
# 543              WND.com
# 544          Yahoo! News
# 546        Yes! Magazine
# Name: news_source, Length: 533, dtype: object

# %%
temp = get_domain('AARP')

# %%
temp = data['news_source'].progress_apply(get_domain)
# Out:
# 100%|██████████| 533/533 [17:02<00:00,  1.92s/it]

# %%
data['news_url'] = temp

# %%
from urllib.parse import urljoin, urlparse
remove_url_params = lambda url: urlparse(url).netloc

# %%
data['netloc'] = data['news_url'].apply(remove_url_params)

# %%
import tldextract
def extract_domain(url):
    ext = tldextract.extract(url)
    return('.'.join([ext.domain, ext.suffix]))

# %%
data['domain'] = data['news_url'].apply(extract_domain)

# %%
data['stance'] = data['rating_num'] - 3

# %%
filtered_data = data[['news_source', 'domain', 'stance', 'type']]

# %%
filtered_data = filtered_data[filtered_data['type'] != 'Author']

# %%
bad_domains = filtered_data['domain'].value_counts().sort_values(ascending=False).iloc[:20].index

# %%
for r in filtered_data[filtered_data['domain'].isin(bad_domains)].iterrows():
    print(r)
# Out:
# (5, news_source              AJ+
# domain         wikipedia.org
# stance                  -2.0
# type              News Media
# Name: 5, dtype: object)
# (13, news_source    American Enterprise Institute
# domain                               aei.org
# stance                                   1.0
# type               Think Tank / Policy Group
# Name: 13, dtype: object)
# (18, news_source     Americans for Tax Reform
# domain                     wikipedia.org
# stance                               2.0
# type           Think Tank / Policy Group
# Name: 18, dtype: object)
# (29, news_source    Association for Psychological Science
# domain                                  google.co.in
# stance                                           0.0
# type                       Think Tank / Policy Group
# Name: 29, dtype: object)
# (49, news_source       Boston Herald
# domain         bostonherald.com
# stance                      1.0
# type                 News Media
# Name: 49, dtype: object)
# (50, news_source    Boston Herald Editorial
# domain                bostonherald.com
# stance                             1.0
# type                        News Media
# Name: 50, dtype: object)
# (69, news_source    Center - Major Media Sources
# domain                           forbes.com
# stance                                  0.0
# type                             News Media
# Name: 69, dtype: object)
# (95, news_source    CNN (Web News)
# domain                cnn.com
# stance                   -1.0
# type               News Media
# Name: 95, dtype: object)
# (96, news_source    CNN - Editorial
# domain                 cnn.com
# stance                    -2.0
# type                News Media
# Name: 96, dtype: object)
# (97, news_source       CNS News
# domain         cnsnews.com
# stance                 2.0
# type            News Media
# Name: 97, dtype: object)
# (98, news_source    CNSNews.com
# domain         cnsnews.com
# stance                 2.0
# type            News Media
# Name: 98, dtype: object)
# (105, news_source        Countable
# domain         wikipedia.org
# stance                   0.0
# type              News Media
# Name: 105, dtype: object)
# (130, news_source       Democracy Now
# domain         democracynow.org
# stance                     -2.0
# type                 News Media
# Name: 130, dtype: object)
# (153, news_source     Fact Checker Blog
# domain         washingtonpost.com
# stance                        0.0
# type                   News Media
# Name: 153, dtype: object)
# (158, news_source      Family Research Council
# domain                      google.co.in
# stance                               1.0
# type           Think Tank / Policy Group
# Name: 158, dtype: object)
# (164, news_source           Food Democracy Now
# domain                  democracynow.org
# stance                              -1.0
# type           Think Tank / Policy Group
# Name: 164, dtype: object)
# (165, news_source        Forbes
# domain         forbes.com
# stance                0.0
# type           News Media
# Name: 165, dtype: object)
# (167, news_source    Fox News Latino
# domain             foxnews.com
# stance                     2.0
# type                News Media
# Name: 167, dtype: object)
# (168, news_source    Fox News Opinion
# domain              foxnews.com
# stance                      2.0
# type                 News Media
# Name: 168, dtype: object)
# (169, news_source    Fox Online News
# domain             foxnews.com
# stance                     1.0
# type                News Media
# Name: 169, dtype: object)
# (172, news_source                 Freakonomics
# domain                        google.com
# stance                               0.0
# type           Think Tank / Policy Group
# Name: 172, dtype: object)
# (182, news_source     Google News
# domain         google.co.in
# stance                 -1.0
# type             News Media
# Name: 182, dtype: object)
# (198, news_source           HotAir
# domain         wikipedia.org
# stance                   1.0
# type              News Media
# Name: 198, dtype: object)
# (200, news_source     Howard Kurtz
# domain         wikipedia.org
# stance                   0.0
# type              News Media
# Name: 200, dtype: object)
# (217, news_source          Jacobin
# domain         wikipedia.org
# stance                  -2.0
# type              News Media
# Name: 217, dtype: object)
# (230, news_source          Jezebel
# domain         wikipedia.org
# stance                  -2.0
# type              News Media
# Name: 230, dtype: object)
# (253, news_source             KATU
# domain         wikipedia.org
# stance                   0.0
# type              News Media
# Name: 253, dtype: object)
# (266, news_source    Left - Major Media Sources
# domain                    pewresearch.org
# stance                               -2.0
# type                           News Media
# Name: 266, dtype: object)
# (277, news_source    Louisville Courier-Journal
# domain                courier-journal.com
# stance                               -1.0
# type                           News Media
# Name: 277, dtype: object)
# (324, news_source    NBC Today Show
# domain           facebook.com
# stance                   -1.0
# type               News Media
# Name: 324, dtype: object)
# (332, news_source    New York Times - News
# domain                   nytimes.com
# stance                          -1.0
# type                      News Media
# Name: 332, dtype: object)
# (333, news_source    New York Times - Opinion
# domain                      nytimes.com
# stance                             -2.0
# type                         News Media
# Name: 333, dtype: object)
# (343, news_source    NPR Editorial
# domain               npr.org
# stance                  -1.0
# type              News Media
# Name: 343, dtype: object)
# (344, news_source    NPR Online News
# domain                 npr.org
# stance                     0.0
# type                News Media
# Name: 344, dtype: object)
# (347, news_source    Orange County Register
# domain                  wikipedia.org
# stance                            1.0
# type                       News Media
# Name: 347, dtype: object)
# (362, news_source       PJ Media
# domain         pjmedia.com
# stance                 1.0
# type            News Media
# Name: 362, dtype: object)
# (363, news_source       PJ Media
# domain         pjmedia.com
# stance                 2.0
# type            News Media
# Name: 363, dtype: object)
# (368, news_source            Prager University
# domain                     wikipedia.org
# stance                               2.0
# type           Think Tank / Policy Group
# Name: 368, dtype: object)
# (371, news_source    Progressive Voices of Iowa
# domain                       facebook.com
# stance                               -2.0
# type                           News Media
# Name: 371, dtype: object)
# (372, news_source    Project Veritas
# domain           wikipedia.org
# stance                     1.0
# type                News Media
# Name: 372, dtype: object)
# (389, news_source     Red State
# domain           imdb.com
# stance                2.0
# type           News Media
# Name: 389, dtype: object)
# (400, news_source    Right - Major Media Sources
# domain                     pewresearch.org
# stance                                 2.0
# type                            News Media
# Name: 400, dtype: object)
# (402, news_source    Right Side News
# domain             youtube.com
# stance                     2.0
# type                News Media
# Name: 402, dtype: object)
# (431, news_source      Splinter
# domain         google.com
# stance               -2.0
# type           News Media
# Name: 431, dtype: object)
# (433, news_source    State Journal
# domain         wikipedia.org
# stance                  -1.0
# type              News Media
# Name: 433, dtype: object)
# (446, news_source    Test Source
# domain         youtube.com
# stance                 0.0
# type            News Media
# Name: 446, dtype: object)
# (455, news_source    The Courier-Journal
# domain         courier-journal.com
# stance                        -1.0
# type                    News Media
# Name: 455, dtype: object)
# (457, news_source    The Daily Show (humor)
# domain                       imdb.com
# stance                           -1.0
# type                       News Media
# Name: 457, dtype: object)
# (474, news_source    The Justice
# domain          google.com
# stance                -1.0
# type            News Media
# Name: 474, dtype: object)
# (479, news_source    The Observer (New York)
# domain                   wikipedia.org
# stance                             0.0
# type                        News Media
# Name: 479, dtype: object)
# (480, news_source       The Oracle
# domain         wikipedia.org
# stance                   0.0
# type              News Media
# Name: 480, dtype: object)
# (485, news_source    The Republican
# domain          wikipedia.org
# stance                    0.0
# type               News Media
# Name: 485, dtype: object)
# (488, news_source    The Sacramento Bee
# domain              wikipedia.org
# stance                       -1.0
# type                   News Media
# Name: 488, dtype: object)
# (523, news_source    Wall Street Journal - Editorial
# domain                                 wsj.com
# stance                                     1.0
# type                                News Media
# Name: 523, dtype: object)
# (524, news_source    Wall Street Journal - News
# domain                            wsj.com
# stance                                0.0
# type                           News Media
# Name: 524, dtype: object)
# (530, news_source       Washington Post
# domain         washingtonpost.com
# stance                       -1.0
# type                   News Media
# Name: 530, dtype: object)

# %%
filtered_data[filtered_data['domain'].isin(bad_domains)]
# Out:
#                                news_source               domain  stance  \
# 5                                      AJ+        wikipedia.org    -2.0
# 13           American Enterprise Institute              aei.org     1.0
# 18                Americans for Tax Reform        wikipedia.org     2.0
# 29   Association for Psychological Science         google.co.in     0.0
# 49                           Boston Herald     bostonherald.com     1.0
# 50                 Boston Herald Editorial     bostonherald.com     1.0
# 69            Center - Major Media Sources           forbes.com     0.0
# 95                          CNN (Web News)              cnn.com    -1.0
# 96                         CNN - Editorial              cnn.com    -2.0
# 97                                CNS News          cnsnews.com     2.0
# 98                             CNSNews.com          cnsnews.com     2.0
# 105                              Countable        wikipedia.org     0.0
# 130                          Democracy Now     democracynow.org    -2.0
# 153                      Fact Checker Blog   washingtonpost.com     0.0
# 158                Family Research Council         google.co.in     1.0
# 164                     Food Democracy Now     democracynow.org    -1.0
# 165                                 Forbes           forbes.com     0.0
# 167                        Fox News Latino          foxnews.com     2.0
# 168                       Fox News Opinion          foxnews.com     2.0
# 169                        Fox Online News          foxnews.com     1.0
# 172                           Freakonomics           google.com     0.0
# 182                            Google News         google.co.in    -1.0
# 198                                 HotAir        wikipedia.org     1.0
# 200                           Howard Kurtz        wikipedia.org     0.0
# 217                                Jacobin        wikipedia.org    -2.0
# 230                                Jezebel        wikipedia.org    -2.0
# 253                                   KATU        wikipedia.org     0.0
# 266             Left - Major Media Sources      pewresearch.org    -2.0
# 277             Louisville Courier-Journal  courier-journal.com    -1.0
# 324                         NBC Today Show         facebook.com    -1.0
# 332                  New York Times - News          nytimes.com    -1.0
# 333               New York Times - Opinion          nytimes.com    -2.0
# 343                          NPR Editorial              npr.org    -1.0
# 344                        NPR Online News              npr.org     0.0
# 347                 Orange County Register        wikipedia.org     1.0
# 362                               PJ Media          pjmedia.com     1.0
# 363                               PJ Media          pjmedia.com     2.0
# 368                      Prager University        wikipedia.org     2.0
# 371             Progressive Voices of Iowa         facebook.com    -2.0
# 372                        Project Veritas        wikipedia.org     1.0
# 389                              Red State             imdb.com     2.0
# 400            Right - Major Media Sources      pewresearch.org     2.0
# 402                        Right Side News          youtube.com     2.0
# 431                               Splinter           google.com    -2.0
# 433                          State Journal        wikipedia.org    -1.0
# 446                            Test Source          youtube.com     0.0
# 455                    The Courier-Journal  courier-journal.com    -1.0
# 457                 The Daily Show (humor)             imdb.com    -1.0
# 474                            The Justice           google.com    -1.0
# 479                The Observer (New York)        wikipedia.org     0.0
# 480                             The Oracle        wikipedia.org     0.0
# 485                         The Republican        wikipedia.org     0.0
# 488                     The Sacramento Bee        wikipedia.org    -1.0
# 523        Wall Street Journal - Editorial              wsj.com     1.0
# 524             Wall Street Journal - News              wsj.com     0.0
# 530                        Washington Post   washingtonpost.com    -1.0
#
#                           type
# 5                   News Media
# 13   Think Tank / Policy Group
# 18   Think Tank / Policy Group
# 29   Think Tank / Policy Group
# 49                  News Media
# 50                  News Media
# 69                  News Media
# 95                  News Media
# 96                  News Media
# 97                  News Media
# 98                  News Media
# 105                 News Media
# 130                 News Media
# 153                 News Media
# 158  Think Tank / Policy Group
# 164  Think Tank / Policy Group
# 165                 News Media
# 167                 News Media
# 168                 News Media
# 169                 News Media
# 172  Think Tank / Policy Group
# 182                 News Media
# 198                 News Media
# 200                 News Media
# 217                 News Media
# 230                 News Media
# 253                 News Media
# 266                 News Media
# 277                 News Media
# 324                 News Media
# 332                 News Media
# 333                 News Media
# 343                 News Media
# 344                 News Media
# 347                 News Media
# 362                 News Media
# 363                 News Media
# 368  Think Tank / Policy Group
# 371                 News Media
# 372                 News Media
# 389                 News Media
# 400                 News Media
# 402                 News Media
# 431                 News Media
# 433                 News Media
# 446                 News Media
# 455                 News Media
# 457                 News Media
# 474                 News Media
# 479                 News Media
# 480                 News Media
# 485                 News Media
# 488                 News Media
# 523                 News Media
# 524                 News Media
# 530                 News Media

# %%
filtered_data[['news_source', 'domain', 'stance']].to_csv(os.path.join(base_dir, 'data', '02_processed', 'allsides_w_domains.csv'))
